# %%
import pandas as pd
import plotly.express as px

# %%
px.data.gapminder()
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
df= px.data.gapminder()
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
px.bar(df,x='continent',y='pop',color='continent',hover_data=['continent'])

# %%
kenya_data = df.query("country =='Kenya'")
kenya_data
# Out:
#     country continent  year  lifeExp       pop    gdpPercap iso_alpha  iso_num
# 816   Kenya    Africa  1952   42.270   6464046   853.540919       KEN      404
# 817   Kenya    Africa  1957   44.686   7454779   944.438315       KEN      404
# 818   Kenya    Africa  1962   47.949   8678557   896.966373       KEN      404
# 819   Kenya    Africa  1967   50.654  10191512  1056.736457       KEN      404
# 820   Kenya    Africa  1972   53.559  12044785  1222.359968       KEN      404
# 821   Kenya    Africa  1977   56.155  14500404  1267.613204       KEN      404
# 822   Kenya    Africa  1982   58.766  17661452  1348.225791       KEN      404
# 823   Kenya    Africa  1987   59.339  21198082  1361.936856       KEN      404
# 824   Kenya    Africa  1992   59.285  25020539  1341.921721       KEN      404
# 825   Kenya    Africa  1997   54.407  28263827  1360.485021       KEN      404
# 826   Kenya    Africa  2002   50.992  31386842  1287.514732       KEN      404
# ...

# %%
kenya_data = df.query("country =='Kenya'")
kenya_data
# Out:
#     country continent  year  lifeExp       pop    gdpPercap iso_alpha  iso_num
# 816   Kenya    Africa  1952   42.270   6464046   853.540919       KEN      404
# 817   Kenya    Africa  1957   44.686   7454779   944.438315       KEN      404
# 818   Kenya    Africa  1962   47.949   8678557   896.966373       KEN      404
# 819   Kenya    Africa  1967   50.654  10191512  1056.736457       KEN      404
# 820   Kenya    Africa  1972   53.559  12044785  1222.359968       KEN      404
# 821   Kenya    Africa  1977   56.155  14500404  1267.613204       KEN      404
# 822   Kenya    Africa  1982   58.766  17661452  1348.225791       KEN      404
# 823   Kenya    Africa  1987   59.339  21198082  1361.936856       KEN      404
# 824   Kenya    Africa  1992   59.285  25020539  1341.921721       KEN      404
# 825   Kenya    Africa  1997   54.407  28263827  1360.485021       KEN      404
# 826   Kenya    Africa  2002   50.992  31386842  1287.514732       KEN      404
# ...

# %%
px.line(kenya_data,x='year',y='pop',labels={"pop":"Population"},markers='o',hover_data=['year','lifeExp','gdpPercap'])

# %%
stocks =px.data.stocks()
stocks.head()
# Out:
#          date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0  2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1  2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2  2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3  2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4  2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708

# %%
plt.figure(figsize=(10,7))
fig =px.line(stocks,x='date',y=['GOOG','AMZN','FB'])
fig.update_layout(width=1000,height=500)
fig.show()

# %%
iris = px.data.iris()
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %%
# color as a categorical variable
fig = px.scatter(iris,x='sepal_length',y='sepal_width',color='species',size='petal_length')
fig.show()

# %%
# color as a continuous variable
# symbol give the shape
fig = px.scatter(iris,x='sepal_length',y='sepal_width',color='petal_width',symbol='species')
fig.show()

# %%
tips = px.data.tips()
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig=px.scatter(tips,x='total_bill',y='tip',facet_col='sex',facet_row='time',color='smoker')
fig.update_layout(height=500)
fig.show()

# %%
fig=px.scatter(tips,x='total_bill',y='tip',trendline='ols')
fig.show()

# %% [markdown]
# ##### Histogram

# %%
fig = px.histogram(tips,x='total_bill'b)
fig.show()

# %%
fig = px.histogram(tips,x='total_bill',nbins=20)
fig.show()

# %% [markdown]
# ##### Box plot

# %%
fig = px.box(tips,y='total_bill')
fig.show()

# %%
fig = px.box(tips,x='time',y='total_bill',points='all')
fig.show()

# %%
fig = px.box(tips,x='time',y='total_bill',points='outliers',color='smoker')
fig.show()

# %%
fig = px.box(tips,x='time',y='total_bill',points='outliers',color='smoker',notched=True,title='Outliers in the total bill')
fig.show()

# %%
# get the points and not the box
fig = px.strip(tips,x='day',y='tip')
fig.show()

# %% [markdown]
# ###### Violin chart

# %%
fig = px.violin(tips,y='total_bill')
fig.show()

# %%
fig = px.violin(tips,y='total_bill',points='all',box=True)
fig.show()

# %%
fig = px.violin(tips,y='tip',color='time',violinmode='overlay',hover_data=tips.columns)
fig.show()

# %%
fig = px.violin(tips,y='total_bill')
fig.update_traces(quartilemethod='exclusive')
fig.show()
